# %%
import numpy as np
import pandas as pd

from sklearn.linear_model import LogisticRegression

# %%
train_df = pd.read_csv('data/train.csv')
test_df = pd.read_csv('data/test.csv')

# %%
train_x = train_df.iloc[:, 1:11]  # use only first 10 features
test_x = test_df.iloc[:, 1:11]
train_y = np.array(train_df["target"].map(lambda x: int(x[-1]) - 1))

# %%
model = LogisticRegression()
model.fit(train_x, train_y)
# Out:
# LogisticRegression()

# %%
pred_test = model.predict_proba(test_x)

# %%
pred_test
# Out:
# array([[0.08454329, 0.59461184, 0.20281602, 0.11802885],
#        [0.09462928, 0.58195424, 0.21075967, 0.1126568 ],
#        [0.08144455, 0.56807383, 0.21100438, 0.13947724],
#        ...,
#        [0.08161843, 0.56868705, 0.21261769, 0.13707683],
#        [0.0850656 , 0.58452574, 0.19843394, 0.13197472],
#        [0.08243542, 0.56787547, 0.21520944, 0.13447967]])

# %%
sample_df.to_csv("submission.csv", index=False)
